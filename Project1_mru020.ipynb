# %%
import numpy as np
import pandas as pd

# %%
class node:
    def __init__(self, feature, value, left_child=None, right_child=None):
        self.feature = feature
        self.value = value

    def set_left(node):
        self.left_child = node

# %%
class decisiontree:
    def __init__(self, root):
        self.root = root
